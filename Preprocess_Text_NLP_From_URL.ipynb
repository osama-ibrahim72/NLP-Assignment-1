# %%
import re
import nltk
import requests
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Download NLTK resources
nltk.download('punkt')  # Download the Punkt tokenizer models
nltk.download('stopwords')  # Download the stopwords corpus
nltk.download('wordnet')  # Download the WordNet lexical database
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# URL to fetch HTML content
url = "https://www.infocontents.com/4/569"

# Fetch HTML content from the URL
response = requests.get(url)
html_code = response.text

# %%
from bs4 import BeautifulSoup
import re

# Function to preprocess and normalize text
def preprocess_and_normalize(text):
    # Remove HTML tags
    soup = BeautifulSoup(text, 'html.parser')  # Parse the HTML content
    clean_content = soup.get_text()  # Extract text from HTML

    # Remove CSS styles
    clean_content = re.sub(r'<style.*?</style>', '', clean_content, flags=re.DOTALL)  # Remove style tags and their content
    clean_content = re.sub(r'<link.*?>', '', clean_content, flags=re.DOTALL)  # Remove link tags

    # Convert text to lowercase
    text = clean_content.lower()  # Convert text to lowercase
    # Remove punctuation using regular expression
    text = re.sub(r'[^\w\s]', '', text)  # Remove non-alphanumeric characters
    # Tokenize the text into words
    tokens = word_tokenize(text)  # Tokenize the text into words
    # Remove stopwords (common words that don't contribute much to the meaning)
    stop_words = set(stopwords.words('english'))  # Get English stopwords
    filtered_tokens = [word for word in tokens if word not in stop_words]  # Filter out stopwords
    # Lemmatize words to their base form
    lemmatizer = WordNetLemmatizer()  # Initialize WordNet lemmatizer
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]  # Lemmatize tokens
    # Join the lemmatized tokens back into a single string
    return ' '.join(lemmatized_tokens)  # Return preprocessed text as a single string

# %%
# Print raw HTML text
print("Raw HTML text:")
print(html_code)
# Out:
# Raw HTML text:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>infocontents</title>
# <meta name="keywords" content />
# <meta name="description" content>
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link href="/static/themes/inforok-hei/assets/img/icon.png" rel="shortcut icon" type="image/x-icon">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
# <link rel="stylesheet" href="/static/themes/inforok-hei/assets/font/iconfont.css">
# <link rel="stylesheet" href="/static/themes/inforok-hei/assets/css/main.css?id=20230327">
# <script type="text/javascript" src="/static/themes/inforok-hei/assets/js/jquery-1.10.2.min.js"></script>
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-H4BPS0ZPV9"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-H4BPS0ZPV9');
# </script>
# <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     var slot = googletag.defineOutOfPageSlot('/22965457064/infocontents-569/infocontents569-inter-01', googletag.enums.OutOfPageFormat.INTERSTITIAL);
#              // Slot returns null if the page or device does not support interstitials
#              if (slot) slot.addService(googletag.pubads());
#              googletag.enableServices();
#              // Consider delaying until first div on page
#              googletag.display(slot);
#           });
#        </script>
# <div class="gtranslate_wrapper"></div>
# <script>window.gtranslateSettings = {"default_language":"ar","native_language_names":true,"detect_browser_language":true,"languages":["ar","en"],"wrapper_selector":".gtranslate_wrapper","switcher_horizontal_position":"inline"}</script>
# <script src="https://cdn.gtranslate.net/widgets/latest/float.js" defer></script>
# <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/22965457064/infocontents-569/infocontents569-sy01', [300, 250], 'div-gpt-ad-1710901650550513-0').addService(googletag.pubads());
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
# </script>
# </head>
# <body>
# <header>
# <a id="menu_btn" href="javascript:;"><i class="iconfont icon-gengduo2"></i></a>
# <a class="branch" href="/4/569"><img src height="40" alt></a>
# <a id="search_btn" href="javascript:;"><i class="iconfont icon-sousuo"></i></a>
# </header>
# <div class="categories">
# <nav>
# <a href="/4/569">HOME</a>
# </nav>
# </div>
# <div class="search_Mask">
# <form action="/4/569/search" class="search_box" method="get">
# <input name="q" type="text" placeholder="Search" id="searchB" autocomplete="off">
# <button class="submit" type="submit"><i class="iconfont icon-sousuo"></i></button>
# </form>
# </div>
# <div class="ad">
#
# <div id="div-gpt-ad-1710901650550513-0" style="min-width: 300px; min-height: 250px;">
# <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1710901650550513-0'); });
#   </script>
# </div> </div>
# <div class="pat_2">
# <h2 class="pat_title">TODY’S PICKS</h2>
# <div class="big">
# <a href="https://www.infocontents.com/4/569/news/6879.html" class="big_item">
# <div class="them"><img src="/storage/202403/ee00af2bad03f33f8d0a4cff36db27ed.jpg" alt="XAU/USD: Gold sparkles to new all-time high of $2,160 as central banks buy big"></div>
# <dl>
# <dt>XAU/USD: Gold sparkles to new all-time high of $2,160 as central banks buy big</dt>
# <dd>Gold(XAUUSD)hit a record high in early trading on Thursday,with a range of factors driving demand for the precious metal.xauusd once surged to a record high of$2,160 an ounce,up just 0.4%in today's opening trade.Gold has never closed in the red in the past seven sessions,gaining a cumulative 6.5%.</dd>
# </dl>
# <span>8 Mar,2024</span>
# </a>
# <a href="https://www.infocontents.com/4/569/news/6878.html" class="big_item">
# <div class="them"><img src="/storage/202403/57e72196dc3753f0b23cb2da131ecacc.jpg" alt="Interest rate cut bets increase Central Banks' strong purchases Risk aversion demand continues to push gold prices to new highs"></div>
# <dl>
# <dt>Interest rate cut bets increase Central Banks' strong purchases Risk aversion demand continues to push gold prices to new highs</dt>
# <dd>Gold prices surged to record highs on Thursday(7),continuing this week's record-breaking rally,as central bank purchases and safe-haven demand continued to drive gold prices higher on increased bets of a U.S.interest rate cut.</dd>
# </dl>
# <span>8 Mar,2024</span>
# </a>
# </div>
# <h2 class="pat_title">Most Recent</h2>
# <ul class="item_box">
# <li>
# <a href="https://www.infocontents.com/4/569/news/6877.html">
# <dl>
# <dt>IEA says global supply and demand balanced Brent flat WTI down</dt>
# <dd>International oil prices closed mixed on Thursday(7),with the global benchmark Brent crude flat but the US benchmark WTI crude down slightly.</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6870.html">
# <dl>
# <dt>Gold surges to record highs above $2,160 as Powell touts rate cuts</dt>
# <dd>Gold prices reached a historic high in Asian trade on Thursday, driven mainly by remarks from Federal Reserve Chair Jerome Powell indicating that the central bank would reduce interest rates in 2024. </dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6623.html">
# <dl>
# <dt>Markets concerned about Middle East situation Crude oil closes higher, U.S. producers cut production, natural gas surges more than 12%.</dt>
# <dd>International oil prices closed higher in range-trading on Wednesday(21)as investors focused on developments in the Middle East and weighed the outlook for global crude demand.</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6607.html">
# <dl>
# <dt>U.S. Dollar Tumbles, Markets Focus on Fed Meeting Minutes Gold Hits One-Week Highs</dt>
# <dd>Tuesday(20)saw a surge in gold prices to over a one-week high as the US dollar declined and investors'attention shifted to the minutes of the most recent Federal Reserve(Fed)monetary policy meeting in hopes of gaining further insight on potential interest rate reductions.</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6606.html">
# <dl>
# <dt>Oil prices fall from last week's 3-month highs amid concerns over tension in the Middle East.</dt>
# <dd>As US traders resumed trading following the President's Day holiday,international oil prices closed lower on Tuesday,20.However,downside was restricted by worries about the Middle East,as Iranian-backed Houthi terrorists assaulted cargo ships.</dd>
# </dl>
# </a>
# </li>
# </ul>
# </div>
# <div class="pat_1">
# <h2 class="pat_title">TRENDING STORIES</h2>
# <ul>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6539.html">
# <div class="thum">
# <img src="/storage/202402/ab01dbd7af6172c7e478b32964cf4d8d.jpg" alt="Fed eagle haze not dissipated geopolitical situation worsened oil prices rose nearly 1%." width="180" height="100">
# </div>
# <dl>
# <dt>Fed eagle haze not dissipated geopolitical situation worsened oil prices rose nearly 1%.</dt>
# <dd>6 Feb,2024</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6455.html">
# <div class="thum">
# <img src="/storage/202403/d6fcec9a7b8c83aaa0d2f8f61d5dc6d9.jpg" alt="Bauer throws cold water on March rate cut, spot gold turns lower" width="180" height="100">
# </div>
# <dl>
# <dt>Bauer throws cold water on March rate cut, spot gold turns lower</dt>
# <dd>1 Feb,2024</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6410.html">
# <div class="thum">
# <img src="/storage/202403/8b43f2f4e37ad9cd83048b522f5f6b49.jpg" alt="U.S. May Avoid Middle East Conflict Escalation China's Demand Outlook Worries Oil Prices Pull Back, Close Lower" width="180" height="100">
# </div>
# <dl>
# <dt>U.S. May Avoid Middle East Conflict Escalation China's Demand Outlook Worries Oil Prices Pull Back, Close Lower</dt>
# <dd>30 Jan,2024</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6030.html">
# <div class="thum">
# <img src="/storage/202403/02bac0e1cd7a99d5698f3dd8118ad945.jpg" alt="Expected Fed interest rate cut, spot gold price rises, overall trading is light" width="180" height="100">
# </div>
# <dl>
# <dt>Expected Fed interest rate cut, spot gold price rises, overall trading is light</dt>
# <dd>27 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/6027.html">
# <div class="thum">
# <img src="/storage/202403/dd8d774cea15f40c7c83a8d6b70bb0ea.jpg" alt="The situation in the Red Sea is heating up, and Yemeni Husai militants are launching attacks on merchant ships again" width="180" height="100">
# </div>
# <dl>
# <dt>The situation in the Red Sea is heating up, and Yemeni Husai militants are launching attacks on merchant ships again</dt>
# <dd>27 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/5906.html">
# <div class="thum">
# <img src="/storage/202312/1e6bf0254ccde9f7fd276b2e81933656.jpg" alt="Looking forward to Fed rate cuts, US dollar and US bond yields falling, gold continuing to rise" width="180" height="100">
# </div>
# <dl>
# <dt>Looking forward to Fed rate cuts, US dollar and US bond yields falling, gold continuing to rise</dt>
# <dd>20 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/5883.html">
# <div class="thum">
# <img src="/storage/202312/a5db04c31e3df035ac815b9db4808f50.jpg" alt="Buy on dips, enter gold prices rise slightly, waiting for inflation data to be released" width="180" height="100">
# </div>
# <dl>
# <dt>Buy on dips, enter gold prices rise slightly, waiting for inflation data to be released</dt>
# <dd>19 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/5882.html">
# <div class="thum">
# <img src="/storage/202312/1c0fef7cebb25aa92845f46abbb5514e.jpg" alt="BP suspends Red Sea transportation of crude oil to reach a two-week high to prevent attacks from Hussery rebels" width="180" height="100">
# </div>
# <dl>
# <dt>BP suspends Red Sea transportation of crude oil to reach a two-week high to prevent attacks from Hussery rebels</dt>
# <dd>19 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/5862.html">
# <div class="thum">
# <img src="/storage/202312/1c0fef7cebb25aa92845f46abbb5514e.jpg" alt="Red Sea transportation risk rises sharply. Crude oil sees its first weekly increase in 8 weeks" width="180" height="100">
# </div>
# <dl>
# <dt>Red Sea transportation risk rises sharply. Crude oil sees its first weekly increase in 8 weeks</dt>
# <dd>18 Dec,2023</dd>
# </dl>
# </a>
# </li>
# <li>
# <a href="https://www.infocontents.com/4/569/news/5861.html">
# <div class="thum">
# <img src="/storage/202312/95b85018541fe04061025cc3bf238cc9.jpg" alt="The Fed may cut interest rates next year, and the gold weekly closing higher" width="180" height="100">
# </div>
# <dl>
# <dt>The Fed may cut interest rates next year, and the gold weekly closing higher</dt>
# <dd>18 Dec,2023</dd>
# </dl>
# </a>
# </li>
# </ul>
# </div>
# <div class="pat_3">
# <h2 class="pat_title">BUSINESS</h2>
# <a class="big" href="https://www.infocontents.com/4/569/news/5860.html">
# <div class="thum">
# <img src="/storage/202312/e871de271d0e187db58f914ec1513a2b.jpg" alt="Costco Gold Bars are Hot and Sold Over 100 Million US dollars Last Quarter">
# </div>
# </a>
# <div class="list">
# <a href="https://www.infocontents.com/4/569/news/5691.html">OPEC+Increase Production Reduction Power, Saudi Arabia Lowers Sales to Asia Oil Prices</a>
# <a href="https://www.infocontents.com/4/569/news/5654.html">Minister of Energy of Saudi Arabia: If necessary, OPEC+oil production reduction will continue until after March next year</a>
# <a href="https://www.infocontents.com/4/569/news/4697.html">Israeli-Palestinian War: Energy and Military Industry Stocks Lead Gains, Three Major Indices Close Slightly Red</a>
# <a href="https://www.infocontents.com/4/569/news/4696.html">Hamas Assault on Israel, International Oil Prices Soaring by Over 4%</a>
# <a href="https://www.infocontents.com/4/569/news/4541.html">Crude oil hits $90, Goldman Sachs: It's impossible to derail the US economy, nor will consumer spending decline</a>
# <a href="https://www.infocontents.com/4/569/news/4540.html">The US dollar hit a 10 month high and gold slightly declined</a>
# <a href="https://www.infocontents.com/4/569/news/4539.html">Russia relaxes fuel export ban, WTI drops below $90</a>
# <a href="https://www.infocontents.com/4/569/news/4226.html">Focus Turns to Fed Officials' Speeches Gold Goes Black for Third Straight Day</a>
# <a href="https://www.infocontents.com/4/569/news/4225.html">Oil prices have fallen from this year's highs, but U.S. inventories have fallen by more than 6 million barrels, curbing crude's decline.</a>
# <a href="https://www.infocontents.com/4/569/news/4196.html">International Sugar Prices Surge to New Highs Since 2011, Global Stocks May Be Nearly Depleted</a>
# </div>
#
# </div>
# <footer>
# <nav>
# <a href="/4/569/policy.html">PRIVACY</a>
# <a href="/4/569/term.html">TERMS OF USE</a>
# <a href="/4/569/contact.html">CONTACT</a>
# </nav>
# <p>Copyright&copy;2022 infocontents All Rights Reserved.</p>
# </footer>
# <script src="/static/themes/inforok-hei/assets/js/common.js?id=20230324"></script>
# <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#           window.googletag = window.googletag || {cmd: []};
#           googletag.cmd.push(function() {
#              var slot = googletag.defineOutOfPageSlot(
#                   '/22965457064/infocontents-569/infocontents569-anchor-01',
#                   googletag.enums.OutOfPageFormat.BOTTOM_ANCHOR);
#              // Slot returns null if the page or device does not support interstitials
#              if (slot) slot.addService(googletag.pubads());
#              googletag.enableServices();
#              // Consider delaying until first div on page
#              googletag.display(slot);
#           });
# </script>
# </body>
# </html>

# %%
# Preprocess and normalize HTML code
preprocessed_html = preprocess_and_normalize(html_code)

# %%
# Print preprocessed HTML text
print("\nPreprocessed HTML text:")
print(preprocessed_html)
# Out:
# Preprocessed HTML text:
# infocontents home tody pick xauusd gold sparkle new alltime high 2160 central bank buy big goldxauusdhit record high early trading thursdaywith range factor driving demand precious metalxauusd surged record high of2160 ounceup 04in today opening tradegold never closed red past seven sessionsgaining cumulative 65 8 mar2024 interest rate cut bet increase central bank strong purchase risk aversion demand continues push gold price new high gold price surged record high thursday7continuing week recordbreaking rallyas central bank purchase safehaven demand continued drive gold price higher increased bet usinterest rate cut 8 mar2024 recent iea say global supply demand balanced brent flat wti international oil price closed mixed thursday7with global benchmark brent crude flat u benchmark wti crude slightly gold surge record high 2160 powell tout rate cut gold price reached historic high asian trade thursday driven mainly remark federal reserve chair jerome powell indicating central bank would reduce interest rate 2024 market concerned middle east situation crude oil close higher u producer cut production natural gas surge 12 international oil price closed higher rangetrading wednesday21as investor focused development middle east weighed outlook global crude demand u dollar tumble market focus fed meeting minute gold hit oneweek high tuesday20saw surge gold price oneweek high u dollar declined investorsattention shifted minute recent federal reservefedmonetary policy meeting hope gaining insight potential interest rate reduction oil price fall last week 3month high amid concern tension middle east u trader resumed trading following president day holidayinternational oil price closed lower tuesday20howeverdownside restricted worry middle eastas iranianbacked houthi terrorist assaulted cargo ship trending story fed eagle haze dissipated geopolitical situation worsened oil price rose nearly 1 6 feb2024 bauer throw cold water march rate cut spot gold turn lower 1 feb2024 u may avoid middle east conflict escalation china demand outlook worry oil price pull back close lower 30 jan2024 expected fed interest rate cut spot gold price rise overall trading light 27 dec2023 situation red sea heating yemeni husai militant launching attack merchant ship 27 dec2023 looking forward fed rate cut u dollar u bond yield falling gold continuing rise 20 dec2023 buy dip enter gold price rise slightly waiting inflation data released 19 dec2023 bp suspends red sea transportation crude oil reach twoweek high prevent attack hussery rebel 19 dec2023 red sea transportation risk rise sharply crude oil see first weekly increase 8 week 18 dec2023 fed may cut interest rate next year gold weekly closing higher 18 dec2023 business opecincrease production reduction power saudi arabia lower sale asia oil price minister energy saudi arabia necessary opecoil production reduction continue march next year israelipalestinian war energy military industry stock lead gain three major index close slightly red hamas assault israel international oil price soaring 4 crude oil hit 90 goldman sachs impossible derail u economy consumer spending decline u dollar hit 10 month high gold slightly declined russia relaxes fuel export ban wti drop 90 focus turn fed official speech gold go black third straight day oil price fallen year high u inventory fallen 6 million barrel curbing crude decline international sugar price surge new high since 2011 global stock may nearly depleted privacy term use contact copyright2022 infocontents right reserved

# %%
# Tokenize the preprocessed text into words
words = word_tokenize(preprocessed_html)

# %%
# Remove duplicates by converting the list to a set
unique_words = set(words)

# %%
# Print unique words
print("\nUnique words:")
for word in unique_words:
    print(word)
# Out:
# Unique words:
# jerome
# insight
# falling
# stock
# goldman
# transportation
# hamas
# red
# early
# cut
# demand
# last
# 1
# black
# trader
# energy
# recordbreaking
# potential
# military
# war
# rangetrading
# mainly
# reduction
# worsened
# producer
# million
# week
# tuesday20howeverdownside
# nearly
# 18
# closing
# israel
# factor
# minute
# investorsattention
# waiting
# 90
# thursday7continuing
# rebel
# reservefedmonetary
# restricted
# seven
# balanced
# bet
# following
# enter
# major
# reduce
# impossible
# 12
# declined
# today
# data
# thursdaywith
# minister
# export
# fallen
# rise
# overall
# spot
# trading
# economy
# push
# yemeni
# gaining
# asian
# tody
# slightly
# interest
# drive
# continues
# supply
# u
# reserve
# mar2024
# investor
# feb2024
# mixed
# wednesday21as
# purchase
# heating
# gas
# continued
# suspends
# sale
# infocontents
# 65
# oil
# terrorist
# israelipalestinian
# 10
# rate
# production
# dissipated
# historic
# arabia
# opecoil
# yield
# market
# amid
# first
# strong
# higher
# opecincrease
# tension
# ban
# industry
# militant
# new
# 6
# gain
# assaulted
# necessary
# cumulative
# thursday
# east
# natural
# sea
# prevent
# soaring
# since
# attack
# drop
# merchant
# tradegold
# story
# 27
# tuesday20saw
# ounceup
# may
# tumble
# cargo
# sachs
# privacy
# 04in
# lead
# eagle
# expected
# 4
# right
# jan2024
# inflation
# haze
# continue
# contact
# 19
# wti
# bp
# fuel
# alltime
# lower
# driving
# precious
# past
# russia
# escalation
# focused
# 20
# reached
# geopolitical
# surged
# power
# avoid
# consumer
# metalxauusd
# range
# barrel
# straight
# usinterest
# husai
# would
# sessionsgaining
# rallyas
# looking
# third
# launching
# tout
# reserved
# day
# close
# closed
# use
# safehaven
# fall
# dollar
# decline
# international
# 2024
# weighed
# fed
# iranianbacked
# trending
# saudi
# hit
# middle
# hope
# increased
# recent
# cold
# benchmark
# assault
# forward
# situation
# never
# concern
# curbing
# president
# crude
# dip
# sugar
# 2011
# index
# global
# derail
# concerned
# month
# aversion
# spending
# bauer
# ship
# sparkle
# federal
# throw
# holidayinternational
# go
# record
# official
# year
# 8
# see
# powell
# flat
# xauusd
# remark
# high
# 2160
# hussery
# next
# speech
# term
# pick
# buy
# risk
# brent
# back
# of2160
# sharply
# asia
# increase
# policy
# march
# 30
# dec2023
# say
# bond
# twoweek
# inventory
# big
# houthi
# opening
# 3month
# reach
# focus
# outlook
# price
# thursday7with
# water
# three
# meeting
# eastas
# goldxauusdhit
# light
# released
# central
# indicating
# resumed
# turn
# business
# relaxes
# development
# depleted
# iea
# trade
# shifted
# worry
# gold
# conflict
# oneweek
# weekly
# driven
# chair
# china
# bank
# pull
# home
# rose
# copyright2022
# surge
# continuing
